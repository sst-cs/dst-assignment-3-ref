# %% [markdown]
# # Assignment 03 – Data Visualisation
#
# Complete all TODO cells. Keep the required variable names exactly as given.
# Do **not** rename any files.

# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('Agg')   # non-interactive backend for autograding
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Task 1: Load the Data
# Read `movies.csv` into a DataFrame `df`.
# Store the shape in `df_shape` and `.describe()` in `summary_stats`.

# %%
# TODO
df = None
df_shape = None
summary_stats = None

print(df_shape)
display(summary_stats)

# %% [markdown]
# ## Task 2: Histogram of Ratings (fig1)
# Plot a **histogram** of the `rating` column.
# Label both axes and set a title. Store the figure in `fig1`.

# %%
# TODO
fig1 = None
plt.close()

# %% [markdown]
# ## Task 3: Average Rating per Genre (fig2)
# Plot a **bar chart** showing the mean `rating` for each `genre`.
# Set a title. Store in `fig2`.

# %%
# TODO
fig2 = None
plt.close()

# %% [markdown]
# ## Task 4: Votes vs Revenue Scatter (fig3)
# Plot a **scatter plot** of `votes` (x-axis) vs `revenue_million` (y-axis).
# Label both axes and set a title. Store in `fig3`.

# %%
# TODO
fig3 = None
plt.close()

# %% [markdown]
# ## Task 5: Revenue Trend by Year (fig4)
# Plot a **line plot** of the average `revenue_million` per `year`.
# Label both axes and set a title. Store in `fig4`.

# %%
# TODO
fig4 = None
plt.close()

# %% [markdown]
# ## Task 6: Correlation Heatmap (fig5)
# Plot a **heatmap** of the correlation matrix of the numeric columns
# (`year`, `rating`, `votes`, `revenue_million`).
# Set a title. Store in `fig5`.

# %%
# TODO
fig5 = None
plt.close()

# %% [markdown]
# ## Task 7: Top 10 Movies (top_movies)
# Filter and sort `df` to get the **top 10 rows** by `rating` (descending).
# Store in `top_movies`.

# %%
# TODO
top_movies = None
top_movies

# %% [markdown]
# ## Final Check

# %%
required = ['df','df_shape','summary_stats','fig1','fig2','fig3','fig4','fig5','top_movies']
for v in required:
    print(v, 'OK' if v in dir() and globals()[v] is not None else 'MISSING')
